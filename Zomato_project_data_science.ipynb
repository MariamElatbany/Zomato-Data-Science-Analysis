# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('/content/zomato.csv',engine="python",
    on_bad_lines="skip" )
df
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/jalsa-banasha...
# 1     https://www.zomato.com/bangalore/spice-elephan...
# 2     https://www.zomato.com/SanchurroBangalore?cont...
# 3     https://www.zomato.com/bangalore/addhuri-udupi...
# 4     https://www.zomato.com/bangalore/grand-village...
# ...                                                 ...
# 3007  https://www.zomato.com/bangalore/you-n-cane-ja...
# 3008  https://www.zomato.com/bangalore/new-rajadhani...
# 3009  https://www.zomato.com/bangalore/bella-jayanag...
# 3010  https://www.zomato.com/bangalore/polammas-mess...
# 3011  https://www.zomato.com/bangalore/b-m-w-bhookh-...
#
#                                                 address  \
# 0     942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1     2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2     1112, Next to KIMS Medical College, 17th Cross...
# 3     1st Floor, Annakuteera, 3rd Stage, Banashankar...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3012 entries, 0 to 3011
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          3012 non-null   object
#  1   address                      3012 non-null   object
#  2   name                         3012 non-null   object
#  3   online_order                 3012 non-null   object
#  4   book_table                   3012 non-null   object
#  5   rate                         2604 non-null   object
#  6   votes                        3012 non-null   int64
#  7   phone                        2973 non-null   object
#  8   location                     3011 non-null   object
#  9   rest_type                    2999 non-null   object
#  10  dish_liked                   1227 non-null   object
#  11  cuisines                     3008 non-null   object
#  12  approx_cost(for two people)  3009 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df .shape
# Out:
# (3012, 17)

# %% [markdown]
# # **Deleting redundant columns.**

# %%
df.drop(columns=['url','phone', 'reviews_list', 'menu_item',
       'listed_in(type)','cuisines', 'listed_in(city)','location', 'rest_type','address','votes'], inplace=True )

# %%
df
# Out:
#                            name online_order book_table   rate  \
# 0                         Jalsa          Yes        Yes  4.1/5
# 1                Spice Elephant          Yes         No  4.1/5
# 2               San Churro Cafe          Yes         No  3.8/5
# 3         Addhuri Udupi Bhojana           No         No  3.7/5
# 4                 Grand Village           No         No  3.8/5
# ...                         ...          ...        ...    ...
# 3007                 You N Cane          Yes         No    NaN
# 3008        New Rajadhani Spicy          Yes         No  3.7/5
# 3009                      Bella          Yes        Yes  3.9/5
# 3010             Polamma's Mess          Yes         No  4.2/5
# 3011  B.M.W Bhookh Mitaane Wala          Yes         No  3.5/5
#
#                                              dish_liked  \
# 0     Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1     Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# ...

# %% [markdown]
# # **Renaming the columns**

# %%
df.rename(columns={'rate':'rating',},inplace=True)

# %%
df.columns=df.columns.str.replace('_',' ').str.title()
df
# Out:
#                            Name Online Order Book Table Rating  \
# 0                         Jalsa          Yes        Yes  4.1/5
# 1                Spice Elephant          Yes         No  4.1/5
# 2               San Churro Cafe          Yes         No  3.8/5
# 3         Addhuri Udupi Bhojana           No         No  3.7/5
# 4                 Grand Village           No         No  3.8/5
# ...                         ...          ...        ...    ...
# 3007                 You N Cane          Yes         No    NaN
# 3008        New Rajadhani Spicy          Yes         No  3.7/5
# 3009                      Bella          Yes        Yes  3.9/5
# 3010             Polamma's Mess          Yes         No  4.2/5
# 3011  B.M.W Bhookh Mitaane Wala          Yes         No  3.5/5
#
#                                              Dish Liked  \
# 0     Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1     Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# ...

# %% [markdown]
# # **Drop duplicates**

# %%
df.duplicated().sum()
# Out:
# np.int64(1132)

# %%
df.duplicated(subset=['Name']).sum()
# Out:
# np.int64(1357)

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.shape
# Out:
# (1880, 6)

# %% [markdown]
# Remove the NaN values from the dataset
# # **New Section**

# %%
df.isnull().sum()
# Out:
# Name                              0
# Online Order                      0
# Book Table                        0
# Rating                          286
# Dish Liked                     1183
# Approx Cost(For Two People)       3
# dtype: int64

# %%
df['Rating'].dtype
# Out:
# dtype('O')

# %%
df['Rating'] = df['Rating'].astype(str).str.replace('/5', '')

# %%
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')

# %%
df['Rating'].dtype
# Out:
# dtype('float64')

# %%
df['Rating']=df['Rating'].fillna(df['Rating'].mean())

# %%
df['Rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Dish Liked'] = df['Dish Liked'].fillna('Not Available')

# %%
df.isnull().sum()
# Out:
# Name                           0
# Online Order                   0
# Book Table                     0
# Rating                         0
# Dish Liked                     0
# Approx Cost(For Two People)    3
# dtype: int64

# %% [markdown]
# # **Encode Categorical Columns**

# %%
df['Online Order'].dtype
df['Online Order']=df['Online Order'].astype(str)

# %%
df['Online Order']=df['Online Order'].str.lower().str.strip().replace({'Yes':1,'No':0})
